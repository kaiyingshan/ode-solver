# %%
import loader
from sympy import *
init_printing()
from root.solver import *

# %% [markdown]
# Draw the phase portrait for the following system of ode
# $$
#     \vec{\mathbf{x'}} = \begin{bmatrix}
#         -\frac{1}{2} & 1 \\
#         -1 & -\frac{1}{2} \\
#     \end{bmatrix} \vec{\mathbf{x}}
# $$

# %%
# %matplotlib inline
phase_portrait(
    [
        [-1/2, 1],
        [-1, -1/2]
    ],
    -5, 5, -5, 5, 15, "vector field"
)

# %% [markdown]
# Draw the phase portrait for the following system of ode
# $$
#     \vec{\mathbf{x'}} = \begin{bmatrix}
#         -3 & \sqrt{2} \\
#         \sqrt{2} & -2 \\
#     \end{bmatrix} \vec{\mathbf{x}}
# $$

# %%
phase_portrait(
    [
        [-3, 1.414],
        [1.414, -2]
    ],
    -10, 10, -10, 10, 15, "stream"
)
